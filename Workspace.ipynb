# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sn

# %%
global_temps='results-2.csv'
df=pd.read_csv(global_temps)
df.describe()
# Out:
#               year    avg_temp  avg_global_temp          50
# count   266.000000  266.000000       257.000000  217.000000
# mean   1882.500000    8.369474         8.357005    8.294016
# std      76.931788    0.584747         0.451586    0.316970
# min    1750.000000    5.780000         7.236364    7.810600
# 25%    1816.250000    8.082500         8.056364    8.050200
# 50%    1882.500000    8.375000         8.270909    8.205800
# 75%    1948.750000    8.707500         8.640000    8.572200
# max    2015.000000    9.830000         9.603636    9.086800

# %%
local_temps='local_temps.csv'
df2=pd.read_csv(local_temps)
df2
# Out:
#      year     city        country  avg_temp  avg_local_temp       50
# 0    1743  Raleigh  United States      7.81             NaN      NaN
# 1    1744  Raleigh  United States     16.02             NaN      NaN
# 2    1745  Raleigh  United States      7.61             NaN      NaN
# 3    1750  Raleigh  United States     15.02             NaN      NaN
# 4    1751  Raleigh  United States     15.79             NaN      NaN
# ..    ...      ...            ...       ...             ...      ...
# 261  2009  Raleigh  United States     14.90          15.252  14.7618
# 262  2010  Raleigh  United States     15.18          15.295  14.7852
# 263  2011  Raleigh  United States     15.84          15.350  14.8128
# 264  2012  Raleigh  United States     15.97          15.385  14.8484
# 265  2013  Raleigh  United States     16.23          15.526  14.8946
#
# [266 rows x 6 columns]

# %%
df_analysis=pd.read_csv('results-2.csv',usecols=[0,2])
df_analysis
# Out:
#      year  avg_global_temp
# 0    1750              NaN
# 1    1751              NaN
# 2    1752              NaN
# 3    1753              NaN
# 4    1754              NaN
# ..    ...              ...
# 261  2011         9.550000
# 262  2012         9.553636
# 263  2013         9.557273
# 264  2014         9.603636
# 265  2015         9.594000
#
# [266 rows x 2 columns]

# %%
df_analysis_2=pd.read_csv('local_temps.csv',usecols=[0,4])
df_analysis_2
# Out:
#      year  avg_local_temp
# 0    1743             NaN
# 1    1744             NaN
# 2    1745             NaN
# 3    1750             NaN
# 4    1751             NaN
# ..    ...             ...
# 261  2009          15.252
# 262  2010          15.295
# 263  2011          15.350
# 264  2012          15.385
# 265  2013          15.526
#
# [266 rows x 2 columns]

# %%
combined=df.append(df2)
combined=combined.drop(columns=['country','50','city','avg_temp','year'])
table=combined.describe()
table.to_csv('statistics.csv')

# %%
statistics=pd.read_csv('statistics.csv',usecols=[0,1,2],index_col=[0])
data=statistics.values
data
column_labels=df.columns.tolist()
column_labels
index_labels=df.index.tolist()
statistics
# Out:
#        avg_global_temp  avg_local_temp
# count       257.000000      257.000000
# mean          8.357005       14.362245
# std           0.451586        0.491277
# min           7.236364       12.657000
# 25%           8.056364       14.150000
# 50%           8.270909       14.359000
# 75%           8.640000       14.655000
# max           9.603636       15.526000

# %%
ax = plt.gca() #get current axis 
fig = plt.gcf()
fig.set_size_inches(15.5,10.5)


df.plot(kind='line',x='year',y='avg_global_temp',ax=ax,color='blue')
df2.plot(kind='line',x='year',y='avg_local_temp',ax=ax,color='red')
plt.ylabel('Moving Average Temperatures (Celsius)',fontweight="bold",size='18')
plt.xlabel('Year',fontweight="bold",size='18')
plt.title('Line Chart of Global vs. Raleigh, NC  Moving Average Temperature Change over Years',fontweight="bold",size='18')
plt.legend(['Global','Raleigh, NC'],loc='center left')
plt.grid()
plt.table()
plt.savefig('temp.jpg', bbox_inches='tight') #removes whitespace around the image. )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6629e0974938> in <module>
#      11 plt.legend(['Global','Raleigh, NC'],loc='center left')
#      12 plt.grid()
# ---> 13 plt.table()
#      14 plt.savefig('temp.jpg', bbox_inches='tight') #removes whitespace around the image. )
#      15 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in table(cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, edges, **kwargs)
#    2996         colLoc='center', loc='bottom', bbox=None, edges='closed',
#    2997         **kwargs):
# -> 2998     return gca().table(
#    2999         cellText=cellText, cellColours=cellColours, cellLoc=cellLoc,
#    3000         colWidths=colWidths, rowLabels=rowLabels,
#
# ...
